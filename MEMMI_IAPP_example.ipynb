# %%
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="Fig1.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("Fig1.png", width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="Fig1.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("Fig2.png", width=800, height=200)
# Out:
#         <iframe
#             width="800"
#             height="200"
#             src="Fig2.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Analysis

# %% [markdown]
# #!/bin/bash
#
# ***
#
# for ((c=0;c<$nrep;c++));do
#
# ***
#
# cd r$c
#
# ***
#
# for part in $(ls *xtc);do
#
# ***
#
# gmx_mpi trjconv -f $part -s *tpr -o nosolv_$part <<EOF
#
# ***
#
# 1
#
# ***
#
# EOF
#
# ***
#
# done
#
# ***
#
# gmx_mpi trjcat -f "nosolv_"$part -o "r"$c"_cat.xtc" <<EOF
#
# ***
#
# 0
#
# ***
#
# EOF
#
# ***
#
# cd -
#
# ***
#
# done
#
# ***
#
# gmx_mpi trjcat -f r0/r0_cat.xtc r1/r1_cat.xtc r2/r2_cat.xtc r3/r3_cat.xtc r4/r4_cat.xtc r5/r5_cat.xtc r6/r6_cat.xtc r7/r7_cat.xtc -cat -o cat_trjcat.xtc -settime <<EOF
#
# ***
#
# 0
#
# ***
#
# c
#
# ***
#
# c
#
# ***
#
#
# c
#
# ***
#
# c
#
# ***
#
# c
#
# ***
#
# c
#
# ***
#
# c
#
# ***
#
# EOF
#
# gmx_mpi trjconv -f cat_trjcat.xtc -s r0/topol.tpr -o traj.xtc -pbc mol <<EOF
#
# ***
#
# 1
#
# ***
#
# EOF
#
# ***
#
# plumed driver --plumed plumed_analysis.dat --mf_xtc traj.xtc
#
# ***
#
# plumed driver --plumed plumed_analysis_unbiased.dat --mf_xtc traj.xtc
#
# ***
#
# ***
#
# plumed --no-mpi driver --plumed reconstruct.dat --mf_xtc traj.xtc --timestep 10
#
# ***
#
# gmx_mpi trjconv -f cat_traj_recon.gro -s cat_traj_recon.gro -o cat_traj_recon_noh.gro

# %% [markdown]
# ### Load biased and unbiased Collective Variables

# %%
time=np.loadtxt("FULLBIAS")[:, 0]
bias=np.loadtxt("FULLBIAS")[:, 1]
disulf1=np.loadtxt("COLVAR")[:, 1]
disulf2=np.loadtxt("COLVAR")[:, 2]
disulf3=np.loadtxt("COLVAR")[:, 3]
disulf4=np.loadtxt("COLVAR")[:, 4]
disulf5=np.loadtxt("COLVAR")[:, 5]
disulf6=np.loadtxt("COLVAR")[:, 6]
disulf7=np.loadtxt("COLVAR")[:, 7]
disulf8=np.loadtxt("COLVAR")[:, 8]


torsion1=np.loadtxt("COLVAR")[:, 9]
torsion2=np.loadtxt("COLVAR")[:, 10]
torsion3=np.loadtxt("COLVAR")[:, 11]
torsion4=np.loadtxt("COLVAR")[:, 12]
torsion5=np.loadtxt("COLVAR")[:, 13]
torsion6=np.loadtxt("COLVAR")[:, 14]
torsion7=np.loadtxt("COLVAR")[:, 15]
torsion8=np.loadtxt("COLVAR")[:, 16]

contacts1=np.loadtxt("COLVAR")[:, 17]
contacts2=np.loadtxt("COLVAR")[:, 18]
contacts3=np.loadtxt("COLVAR")[:, 19]
contacts4=np.loadtxt("COLVAR")[:, 20]
contacts5=np.loadtxt("COLVAR")[:, 21]
contacts6=np.loadtxt("COLVAR")[:, 22]
contacts7=np.loadtxt("COLVAR")[:, 23]


disulf1_un=np.loadtxt("COLVAR_UNBIASED")[:, 1]
disulf2_un=np.loadtxt("COLVAR_UNBIASED")[:, 2]
disulf3_un=np.loadtxt("COLVAR_UNBIASED")[:, 3]
disulf4_un=np.loadtxt("COLVAR_UNBIASED")[:, 4]
disulf5_un=np.loadtxt("COLVAR_UNBIASED")[:, 5]
disulf6_un=np.loadtxt("COLVAR_UNBIASED")[:, 6]
disulf7_un=np.loadtxt("COLVAR_UNBIASED")[:, 7]
disulf8_un=np.loadtxt("COLVAR_UNBIASED")[:, 8]


torsion1_un=np.loadtxt("COLVAR_UNBIASED")[:, 9]
torsion2_un=np.loadtxt("COLVAR_UNBIASED")[:, 10]
torsion3_un=np.loadtxt("COLVAR_UNBIASED")[:, 11]
torsion4_un=np.loadtxt("COLVAR_UNBIASED")[:, 12]
torsion5_un=np.loadtxt("COLVAR_UNBIASED")[:, 13]
torsion6_un=np.loadtxt("COLVAR_UNBIASED")[:, 14]
torsion7_un=np.loadtxt("COLVAR_UNBIASED")[:, 15]
torsion8_un=np.loadtxt("COLVAR_UNBIASED")[:, 16]


contacts1_un=np.loadtxt("COLVAR_UNBIASED")[:, 17]
contacts2_un=np.loadtxt("COLVAR_UNBIASED")[:, 18]
contacts3_un=np.loadtxt("COLVAR_UNBIASED")[:, 19]
contacts4_un=np.loadtxt("COLVAR_UNBIASED")[:, 20]
contacts5_un=np.loadtxt("COLVAR_UNBIASED")[:, 21]
contacts6_un=np.loadtxt("COLVAR_UNBIASED")[:, 22]
contacts7_un=np.loadtxt("COLVAR_UNBIASED")[:, 23]


KBT = 2.49
weights = np.exp(bias/ KBT) 
weights /= weights.sum()
print(time[0],bias[0],disulf1[0],weights[0])


print(len(time))
#This transforms from a list to a 1 collumn array. The -1 is for unknown rows.  
weights.reshape(-1,1)

# %% [markdown]
# ### Compare biased and unbiased CV Free energy

# %%
eq_steps=20000

value5, bins5=np.histogram(disulf4[eq_steps:-1], bins=30, weights=weights[eq_steps:-1], density=True)
value5_un, bins5_un=np.histogram(disulf4_un[eq_steps:-1], bins=30, density=True)

logvalue5=-np.log(value5)
logvalue5_un=-np.log(value5_un)

plt.plot(bins5_un[:-1],logvalue5_un,'tab:blue',linewidth=3)
plt.plot(bins5[:-1],logvalue5,'tab:red',linewidth=3)
plt.legend( ['EMMI','MEMMI'])

plt.xlabel('$\chi_{3}^{4}$ (rad)' )
plt.ylabel('F (kJ/mol)' )
plt.savefig('Disulf4_FESEMMI_METAD.svg',dpi=400,transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Make a time dependent free energy prediction of a biased CV

# %%
#Number of steps to dismiss for FE calcs.
eq_steps=20000

### disulfide 1 dihedral
value1, bins1=np.histogram(disulf1[eq_steps:50000], bins=30,  weights=weights[eq_steps:50000], density=True)
value2, bins2=np.histogram(disulf1[eq_steps:100000], bins=30,  weights=weights[eq_steps:100000], density=True)
value3, bins3=np.histogram(disulf1[eq_steps:200000], bins=30, weights=weights[eq_steps:200000], density=True)
value4, bins4=np.histogram(disulf1[eq_steps:300000], bins=30, weights=weights[eq_steps:300000], density=True)
value5, bins5=np.histogram(disulf1[eq_steps:400000], bins=30, weights=weights[eq_steps:400000], density=True)
value6, bins6=np.histogram(disulf1[eq_steps:-1], bins=30, weights=weights[eq_steps:-1], density=True)

logvalue1=-np.log(value1)*2.45
logvalue2=-np.log(value2)*2.45
logvalue3=-np.log(value3)*2.45
logvalue4=-np.log(value4)*2.45
logvalue5=-np.log(value5)*2.45
logvalue6=-np.log(value6)*2.45


plt.plot(bins1[:-1],logvalue1,linewidth=2)
plt.plot(bins2[:-1],logvalue2,linewidth=2)
plt.plot(bins3[:-1],logvalue3,linewidth=2)
plt.plot(bins4[:-1],logvalue4,linewidth=2)
plt.plot(bins5[:-1],logvalue5,linewidth=2)
plt.plot(bins6[:-1],logvalue6,linewidth=2)
plt.legend( ['t=500 ns', 't=1 $\mu$s','t=2 $\mu$s','t=3 $\mu$s','t=4 $\mu$s','t=5.5 $\mu$s'],loc='upper right')



plt.xlabel('$\chi_{3}^{1}$ (rad)' )
plt.ylabel('F (kJ/mol)' )
plt.savefig('Disulf1_FES.pdf',dpi=400,transparent=True, bbox_inches='tight')

# %%
#__Torsion__1#Number of steps to dismiss for FE calcs.
eq_steps=20000


value1, bins1=np.histogram(contacts1[eq_steps:50000], bins=30,  weights=weights[eq_steps:50000], density=True)
value2, bins2=np.histogram(contacts1[eq_steps:100000], bins=30,  weights=weights[eq_steps:100000], density=True)
value3, bins3=np.histogram(contacts1[eq_steps:200000], bins=30, weights=weights[eq_steps:200000], density=True)
value4, bins4=np.histogram(contacts1[eq_steps:300000], bins=30, weights=weights[eq_steps:300000], density=True)
value5, bins5=np.histogram(contacts1[eq_steps:400000], bins=30, weights=weights[eq_steps:400000], density=True)
value6, bins6=np.histogram(contacts1[eq_steps:-1], bins=30, weights=weights[eq_steps:-1], density=True)

logvalue1=-np.log(value1)*2.45
logvalue2=-np.log(value2)*2.45
logvalue3=-np.log(value3)*2.45
logvalue4=-np.log(value4)*2.45
logvalue5=-np.log(value5)*2.45
logvalue6=-np.log(value6)*2.45


plt.plot(bins1[:-1],logvalue1,linewidth=2)
plt.plot(bins2[:-1],logvalue2,linewidth=2)
plt.plot(bins3[:-1],logvalue3,linewidth=2)
plt.plot(bins4[:-1],logvalue4,linewidth=2)
plt.plot(bins5[:-1],logvalue5,linewidth=2)
plt.plot(bins6[:-1],logvalue6,linewidth=2)
plt.legend( ['t=500 ns', 't=1 $\mu$s','t=2 $\mu$s','t=3 $\mu$s','t=4 $\mu$s','t=5.5 $\mu$s'],loc='upper left')


plt.ylim(0,80)
plt.xlim(0,2500)
plt.xlabel('$N_{1-2}$ ' )
plt.ylabel('F (kJ/mol)' )
plt.savefig('Contats1_FES.pdf',dpi=400,transparent=True, bbox_inches='tight')



#Number of steps to dismiss for FE calcs.
eq_steps=20000

value1, bins1=np.histogram(torsion1_un[eq_steps:50000], bins=30,  weights=weights[eq_steps:50000], density=True)
value2, bins2=np.histogram(torsion1_un[eq_steps:100000], bins=30,  weights=weights[eq_steps:100000], density=True)
value3, bins3=np.histogram(torsion1_un[eq_steps:200000], bins=30, weights=weights[eq_steps:200000], density=True)
value4, bins4=np.histogram(torsion1_un[eq_steps:300000], bins=30, weights=weights[eq_steps:300000], density=True)
value5, bins5=np.histogram(torsion1_un[eq_steps:400000], bins=30, weights=weights[eq_steps:400000], density=True)
value6, bins6=np.histogram(torsion1_un[eq_steps:-1], bins=30, weights=weights[eq_steps:-1], density=True)

logvalue1=-np.log(value1)*2.45
logvalue2=-np.log(value2)*2.45
logvalue3=-np.log(value3)*2.45
logvalue4=-np.log(value4)*2.45
logvalue5=-np.log(value5)*2.45
logvalue6=-np.log(value6)*2.45


plt.plot(bins1[:-1],logvalue1,linewidth=2)
plt.plot(bins2[:-1],logvalue2,linewidth=2)
plt.plot(bins3[:-1],logvalue3,linewidth=2)
plt.plot(bins4[:-1],logvalue4,linewidth=2)
plt.plot(bins5[:-1],logvalue5,linewidth=2)
plt.plot(bins6[:-1],logvalue6,linewidth=2)
plt.legend( ['t=500 ns', 't=1 $\mu$s','t=2 $\mu$s','t=3 $\mu$s','t=4 $\mu$s','t=5.5 $\mu$s'],loc='upper right')


plt.ylim(0, 20)
plt.xlabel('$t^{1}$ (rad)' )
plt.ylabel('F (kJ/mol)' )
plt.savefig('Torsion1_FES_EMMI.pdf',dpi=400,transparent=True, bbox_inches='tight')

# %%
#Nr Contacts_1
#Number of steps to dismiss for FE calcs.
eq_steps=20000


value1, bins1=np.histogram(contacts1[eq_steps:50000], bins=30,  weights=weights[eq_steps:50000], density=True)
value2, bins2=np.histogram(contacts1[eq_steps:100000], bins=30,  weights=weights[eq_steps:100000], density=True)
value3, bins3=np.histogram(contacts1[eq_steps:200000], bins=30, weights=weights[eq_steps:200000], density=True)
value4, bins4=np.histogram(contacts1[eq_steps:300000], bins=30, weights=weights[eq_steps:300000], density=True)
value5, bins5=np.histogram(contacts1[eq_steps:400000], bins=30, weights=weights[eq_steps:400000], density=True)
value6, bins6=np.histogram(contacts1[eq_steps:-1], bins=30, weights=weights[eq_steps:-1], density=True)

logvalue1=-np.log(value1)*2.45
logvalue2=-np.log(value2)*2.45
logvalue3=-np.log(value3)*2.45
logvalue4=-np.log(value4)*2.45
logvalue5=-np.log(value5)*2.45
logvalue6=-np.log(value6)*2.45


plt.plot(bins1[:-1],logvalue1,linewidth=2)
plt.plot(bins2[:-1],logvalue2,linewidth=2)
plt.plot(bins3[:-1],logvalue3,linewidth=2)
plt.plot(bins4[:-1],logvalue4,linewidth=2)
plt.plot(bins5[:-1],logvalue5,linewidth=2)
plt.plot(bins6[:-1],logvalue6,linewidth=2)
plt.legend( ['t=500 ns', 't=1 $\mu$s','t=2 $\mu$s','t=3 $\mu$s','t=4 $\mu$s','t=5.5 $\mu$s'],loc='upper left')


plt.ylim(0,80)
plt.xlim(0,2500)
plt.xlabel('$N_{1-2}$ ' )
plt.ylabel('F (kJ/mol)' )
plt.savefig('Contats1_FES.pdf',dpi=400,transparent=True, bbox_inches='tight')

# %% [markdown]
# ##### Resample the structural ensemble based on weights.

# %%
KBT = 2.494339 # kJ/mol, 300K
n_replica = 1
top_file = "structure_noh.pdb"

biased_cvs = {}

nframes = {weights.shape[0]}
traj = md.load("cat_traj_recon_noh.gro")

# %%
N = 10000


n_frames = traj.n_frames
inds = np.arange(n_frames)
top = md.load_topology(top_file)
ca_inds = top.select("name CA")
protein_inds= top.select("protein")


    (f"resample").mkdir(exist_ok=True)
    inds_sample = np.random.choice(inds, size=N, replace=False,
                               p=weights / weights.sum())
    traj[inds_sample].atom_slice(protein_inds).save_pdb((f"resample" / f"conf-protein.pdb").as_posix())

# %%
# %%bash
# plumed driver --plumed plumed_error.dat --mf_pdb conf-protein.pdb

# %% [markdown]
# ### Calculate the ensemble averaged relative error per gaussian data point in the GMM

# %%
import os
from glob import glob
filenames=glob("OV_FILE*")
newdf=[]
df0=[]
df1=[]
k=0
ov_dd=read_plumed(file='OV_FILE.dat-1',columns=['Data'],step=1)['Data'].to_list()
for file in filenames:
    if (k==0):
        df=read_plumed(file=file,columns=['ModelScaled'],step=1)
        df0=df['ModelScaled'].to_list()
        
    if (k==1):
        df=read_plumed(file=file,columns=['ModelScaled'],step=1)
        df1=df['ModelScaled'].to_list()
        newdf= np.vstack((df0,df1))
        #print(len(df),file,len(newdf))    
        
    if (k>1):
        dfa=read_plumed(file=file,columns=['ModelScaled'],step=1)
        df=dfa['ModelScaled'].to_list()
        newdf=np.vstack((newdf,df))
        #print(len(df),file,len(newdf),'k>1')
    k+=1

error=open("rel_error.dat","w")
errorlist=[]
for i in range(0,len(ov_dd)):
    ov_md=newdf[:,i].mean()
    if (ov_dd[i]>0):
        error.write("%s %.4f %.4f %.4f\n" % (i,np.abs((1-(ov_md/ov_dd[i]))/np.sqrt(2)),ov_md,ov_dd[i]))
        errorlist.append(np.abs((1-(ov_md/ov_dd[i]))/np.sqrt(2)))

error.close()

counts, bins=np.histogram(errorlist, bins=30,  density=False)

plt.hist(bins[:-1], bins, weights=counts,color='red',linewidth=1)

plt.ylabel('Counts' )
plt.xlabel('σ$_r$' )
plt.savefig("pdf_relerror.pdf", bbox_inches='tight')

# %% [markdown]
# ### Generate a strctural ensemble-based map using gmconvert.
# - gmx trjconv -f conf-protein.pdb -s conf-protein.pdb -o .pdb
# - gmconvert -ipdb 0.pdb -pdbl pdblist -omap EMMI_ensemble.map -a2v R -gw 0.5
# - where pdblist contains:
#
# 0.pdb 1.0
# ***
#
# 1.pdb 1.0
#
# ***
# 2.pdb 1.0
#
# ***
# ...
#
# ### Calculate the local correlation in chimera to produce Fig 2.B
# - open emd_10669_6A.mrc
# - Open EMMI_ensemble.map
# - vop localCorrelation #0 #1 windowSize 5 model #3
# - scolor #0 volume #3 cmap .5,blue:0.75,white:1,red
# - transparency 30 #1
# - colorkey 0,0 0.2,0.05 0.5 blue 0.75 white 1 red
# - Contour level=0.263
